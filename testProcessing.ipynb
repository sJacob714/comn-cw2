# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Task2 tests Question 1

# %%
fiveTest = np.asarray([[842,  49.37665454341213],[937,   59.35790973275731],[893, 73.76672053780987],[941, 72.59458197515939],[887, 48.96578612855184]])

tenTest = np.asarray([[645   ,61.79285018683163],[678   ,67.49603254867442],[600   ,28.797545102546433],[668,   66.95383015896961],[678,   65.72985612300266]])

fifteenTest = np.asarray([[153   ,59.70700687180512],[99   ,65.05997094935672],[88   ,65.46115516123449],[129   ,57.64207635647376],[204   ,50.6281545319939]])

twentyTest = np.asarray([[121   ,52.063688768766504],[73,   65.49861193836401],[87,   68.47556956289303],[115,   51.78057392228784],[97,   58.53420468321362]])

twentyfiveTest = np.asarray([[92   ,50.56198580412211],[118   ,51.64868949598696],[105   ,48.50291980259916],[92   ,57.13136524814487],[118   ,48.117379387350056]])

thirtyTest = np.asarray([[105   ,51.74174383445531],[109   ,48.61012277962667],[92   ,54.91941363076642],[102   ,44.42314488910958],[106   ,59.50415269538772]])

fortyTest = np.asarray([[96   ,47.93243030407741],[110   ,53.391901048246545],[103   ,50.559910248516935],[99   ,49.03616131665823],[113   ,50.2428846707949]])

fiftyTest = np.asarray([[111   ,38.98627522881456],[129   ,38.4598085514186],[105   ,46.641795993752204],[98   ,47.29720211571181],[102   ,49.23072389802668]])

seventyfiveTest = np.asarray([[117   ,24.66544698114947],[105   ,45.11203761078749],[77   ,48.62107098444725],[100   ,39.31473897643629],[109   ,43.83912204420351]])

hundredTest = np.asarray([[98   ,40.8262116467392],[102   ,38.042873056522964],[114   ,33.79237247802324],[101   ,28.243235799948472],[111   ,28.87889709936624]])

testList = [fiveTest, tenTest, fifteenTest, twentyTest, twentyfiveTest, thirtyTest, fortyTest, fiftyTest, seventyfiveTest, hundredTest]

for test in testList:
    print("retransmissions: ",np.average(test.T[0]))
    print("Throughpnut",np.average(test.T[1]))
# Out:
# retransmissions:  900.0
# Throughpnut 60.812330583538106
# retransmissions:  653.8
# Throughpnut 58.15402282400495
# retransmissions:  134.6
# Throughpnut 59.699672774172804
# retransmissions:  98.6
# Throughpnut 59.27052977510499
# retransmissions:  105.0
# Throughpnut 51.19246794764064
# retransmissions:  102.8
# Throughpnut 51.83971556586914
# retransmissions:  104.2
# Throughpnut 50.2326575176588
# retransmissions:  109.0
# Throughpnut 44.12316115754477
# retransmissions:  101.6
# Throughpnut 40.31048331940481
# retransmissions:  105.2
# Throughpnut 33.95671801612002

# %% [markdown]
# BEST TIMEOUT WAS 15ms

# %% [markdown]
# Tak 3 Question 3

# %% [markdown]
# 5ms delay testing, 15 ms timeout

# %%
test1 = [35.21337269594632,33.24237998962849,34.413588592092175,34.31202863630473,33.86370779419765]

test2 = [59.36023793680452,60.50685752226671,55.578606866801664,61.46443867304975,55.977091463922356]

test3 = [99.63762514386657,94.73951458509292,110.1648798835942,97.08941757483083,114.83866549024214]

test4 = [189.9065003565101,200.0943722909859,194.0588263122244,195.12446678716472,178.89163742173997]

test5 = [297.1695393547192,302.4657389847356,291.3857612537616,302.2001555778797,306.3778470569063]

test6 = [30.320936337772338,32.16043207383951,33.051153497790374,29.731701909463347,28.306244821102002]

test7 = [38.36657933641804,42.5300635614781,40.64523038808385,39.750079556544804,47.23248186991622]

test8 = [50.914091082347426,30.923221135787234,36.355246858542145,36.88758143470764,44.26000513950008]

test9 = [29.945031815255295,38.10090576238562,40.31062271809482,33.16216902455671,39.29510496184417]

testList = [test1, test2, test3, test4, test5, test6, test7, test8, test9]

averages1 = []
for test in testList:
    averages1.append(np.average(test))
averages1 = np.asarray(averages1)
print(averages1)
# Out:
# [ 34.20901554  58.57744649 103.29402054 191.61516063 299.91980845
#   30.71409373  41.70488694  39.86802913  36.16276686]

# %% [markdown]
# chose 55ms timeout for 25ms delay testing, cause RTT would be 50ms, but with a bit of leway for variation

# %%
test1 = [9.474998569352113,10.302823324160704,10.896093968505902,11.400712992616437,11.504244639688116]

test2 = [18.0486371449874,19.511202200914404,20.724381527294018,18.55419118711224,18.651437358181013]

test3 = [32.4410148116743,30.49085387017865,31.63588315469483,36.21016584427195,30.05114234920481]

test4 = [52.95615209194028,56.458589100538816,61.84039715217139,63.91565136727625,63.313939538808356]

test5 = [108.04354659016599,103.54979254628599,105.647886240786,101.97156736329612,102.12638873264608]

test6 = [172.96091235155026,165.12142896536,172.88283904714734,164.3543060722252,173.19428333882192]

test7 = [252.0588120393516,232.50519204308677,215.23812002579166,239.73905988454425,256.1091906625313]

test8 = [68.13613346326827,79.27142977712391,78.85546791807654,54.2917530198569,76.5948864410519]

test9 = [87.38156818587287,79.93413082562823,79.34281985984336,78.63910206799136,59.712678945650694]

testList = [test1, test2, test3, test4, test5, test6, test7, test8, test9]

averages2 = []
for test in testList:
    averages2.append(np.average(test))
averages2 = np.asarray(averages2)

print(averages2)
# Out:
# [ 10.7157747   19.09796988  32.16581201  59.69694585 104.26783629
#  169.70275396 239.13007493  71.42993412  77.00205998]

# %% [markdown]
# 205ms timeout, 100ms delay

# %%
test1 = [2.7770929380035554,2.7683130325269376,2.8762042920296267,2.901876279958337,2.7848162818679487]

test2 = [5.004815618611244,5.276068647187974,5.277093295129076,5.305159569860799,5.259412897167755]

test3 = [9.140803932032652,9.546374840648141,9.542502667769687,9.048713821300522,9.3528142266766]

test4 = [16.467817386395023,16.488808940451488,15.305152452630193,17.61720039371582,16.34724740869588]

test5 = [26.938450877315262,27.290584327852518,27.908352345352007,28.360785317654805,26.614153475740416]

test6 = [44.88749618850827,50.141019013469354,47.886488544587465,47.73396040572348,48.39040058632198]

test7 = [79.26685127103012,84.02179969486583,70.64681835947883,70.86780627213064,67.47784545957425]

test8 = [55.7344949709561,89.71329082954773,95.73520416638564,85.04740873224547,85.1100793447609]

test9 =[61.00726645152239,55.113376588999095,49.10399680079566,26.778997841853364,54.46207811181053]

testList = [test1, test2, test3, test4, test5, test6, test7, test8, test9]

averages3 = []
for test in testList:
    averages3.append(np.average(test))
averages3 = np.asarray(averages3)

print(averages3)
# Out:
# [ 2.82166056  5.22451001  9.3262419  16.44524532 27.42246527 47.80787295
#  74.45622421 82.26809561 49.29314316]

# %%
x = [1,2,4,8,16,32,64,128,256]

plt.plot(x, averages1,'bd-', label = "Delay(5ms)")
plt.plot(x, averages2, color='orange',marker = 's', label = "Delay(25ms)")
plt.plot(x, averages3, color = 'grey',marker = '^',label = "Delay(100ms)")

plt.xlabel("Window Size")
plt.ylabel("Throughput(KBps)")
plt.grid(axis='y')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(ticks = x,labels=x)
plt.xscale('log', base = 2)
plt.xticks(x, x)
plt.plot()
# Out:
# []

# %% [markdown]
# Task 4 Question 5

# %%
test1 = [10.224060620406648,9.89177459497142,10.162191345945576,9.60515252772721,9.44397100637189]

test2 = [23.131244146873374,23.69678225710758,23.574722797986976,22.245775976804484,19.356511120297764]

test3 = [20.554538344379214,45.3436141375904,39.11427120189394,38.79848722434344,40.20466785376384]

test4 = [70.04691682319425,86.5503856116152,84.09639182611004,81.07150349775391,77.59737439188467]

test5 = [147.43337842050013,141.45892923482984,140.62470143168508,144.60705450967689,80.69642067595416]

test6 = [226.4533816665974,230.90410398688897,130.6423705424741,273.9992687839281,242.42846627071737]

test7 = [210.6219691443485,213.71531037387263,412.87418917062865,374.5405878257937,424.4140861914191]

test8 = [101.41434746680474,104.1322479119574,62.69589946640824,115.53742929042045,121.70534310455771]

test9 = [131.21320279430657,95.09432932217429,145.128761809489,136.19668682752808,123.9227171610338]

testList = [test1, test2, test3, test4, test5, test6, test7, test8, test9]

for test in testList:
    print(np.average(test))
# Out:
# 9.865430019084549
# 22.401007259814037
# 36.80311575239417
# 79.87251443011161
# 130.96409685452923
# 220.88551825012118
# 327.2332285412125
# 101.09705344802971
# 126.31113958290635
